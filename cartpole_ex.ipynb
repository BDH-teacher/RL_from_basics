# %% [markdown]
# <a href="https://colab.research.google.com/github/BDH-teacher/RL_from_basics/blob/main/cartpole_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup rendering dependencies for Google Colaboratory.

# %%
# !apt-get install -y xvfb ffmpeg > /dev/null 2>&1
# !pip install pyvirtualdisplay pygame moviepy > /dev/null 2>&1

# %% [markdown]
# Install d3rlpy!

# %%
# !pip install d3rlpy
# Out:
# Requirement already satisfied: d3rlpy in /usr/local/lib/python3.12/dist-packages (2.8.1)
# Requirement already satisfied: torch>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (2.8.0+cu126)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (4.67.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (3.15.1)
# Requirement already satisfied: gym>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (0.26.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (8.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (4.15.0)
# Requirement already satisfied: structlog in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (25.5.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (0.4.6)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (0.6.7)
# Requirement already satisfied: gymnasium==1.0.0 in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (1.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from d3rlpy) (1.6.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.0.0->d3rlpy) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.0.0->d3rlpy) (3.1.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.0.0->d3rlpy) (0.0.4)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym>=0.26.0->d3rlpy) (0.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.0->d3rlpy) (3.4.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->d3rlpy) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->d3rlpy) (0.9.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->d3rlpy) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->d3rlpy) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->d3rlpy) (3.6.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.12/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->d3rlpy) (25.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.5.0->d3rlpy) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->d3rlpy) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.5.0->d3rlpy) (3.0.3)

# %% [markdown]
# Setup cartpole dataset.

# %%
import numpy as np

if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

# %%
import d3rlpy
from d3rlpy.datasets import get_cartpole
from d3rlpy.metrics import EnvironmentEvaluator

cql = d3rlpy.algos.DiscreteCQLConfig().create(device='cuda:0')
dataset, env = get_cartpole()
# Out:
# 2025-11-20 08:14.55 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('int32')], shape=[(1,)]) observation_signature=Signature(dtype=[dtype('float32')], shape=[(4,)]) reward_signature=Signature(dtype=[dtype('float32')], shape=[(1,)])
# 2025-11-20 08:14.55 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.DISCRETE: 2>
# 2025-11-20 08:14.55 [info     ] Action size has been automatically determined. action_size=2

# %% [markdown]
# # Setup data-driven deep reinforcement learning algorithm.

# %%
# setup CQL algorithm
cql = d3rlpy.algos.DiscreteCQLConfig().create(device='cuda:0')

# start training
cql.fit(
    dataset,
    n_steps=10000,
    n_steps_per_epoch=1000,
    evaluators={
        'environment': d3rlpy.metrics.EnvironmentEvaluator(env), # evaluate with CartPole-v1 environment
    },
)
# Out:
# 2025-11-20 08:15.53 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float32')], shape=[(4,)]), action_signature=Signature(dtype=[dtype('int32')], shape=[(1,)]), reward_signature=Signature(dtype=[dtype('float32')], shape=[(1,)]), action_space=<ActionSpace.DISCRETE: 2>, action_size=2)
# 2025-11-20 08:15.53 [debug    ] Building models...
# 2025-11-20 08:15.53 [debug    ] Models have been built.
# 2025-11-20 08:15.53 [info     ] Directory is created at d3rlpy_logs/DiscreteCQL_20251120081553
# 2025-11-20 08:15.53 [info     ] Parameters                     params={'observation_shape': [4], 'action_size': 2, 'config': {'type': 'discrete_cql', 'params': {'batch_size': 32, 'gamma': 0.99, 'observation_scaler': {'type': 'none', 'params': {}}, 'action_scaler': {'type': 'none', 'params': {}}, 'reward_scaler': {'type': 'none', 'params': {}}, 'compile_graph': False, 'learning_rate': 6.25e-05, 'optim_factory': {'type': 'adam', 'params': {'clip_grad_norm': None, 'lr_scheduler_factory': {'type': 'none', 'params': {}}, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False}}, 'encoder_factory': {'type': 'default', 'params': {'activation': 'relu', 'use_batch_norm': False, 'dropout_rate': None}}, 'q_func_factory': {'type': 'mean', 'params': {'share_encoder': False}}, 'n_critics': 1, 'target_update_interval': 8000, 'alpha': 1.0}}}
# Epoch 1/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:16.01 [info     ] DiscreteCQL_20251120081553: epoch=1 step=1000 epoch=1 metrics={'time_sample_batch': 0.0005290753841400147, 'time_algorithm_update': 0.0048704886436462405, 'loss': 0.705537933588028, 'td_loss': 0.035360016939695926, 'conservative_loss': 0.6701779159903526, 'time_step': 0.005472167491912842, 'environment': 500.0} step=1000
# 2025-11-20 08:16.01 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_1000.d3
# Epoch 2/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# Moviepy - Building video /content/video/rl-video-episode-27.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-27.mp4
# 2025-11-20 08:16.12 [info     ] DiscreteCQL_20251120081553: epoch=2 step=2000 epoch=2 metrics={'time_sample_batch': 0.000662245512008667, 'time_algorithm_update': 0.005823456525802613, 'loss': 0.6730708175897598, 'td_loss': 0.010519563182722777, 'conservative_loss': 0.662551253914833, 'time_step': 0.006566694021224975, 'environment': 500.0} step=2000
# 2025-11-20 08:16.12 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_2000.d3
# Epoch 3/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:16.21 [info     ] DiscreteCQL_20251120081553: epoch=3 step=3000 epoch=3 metrics={'time_sample_batch': 0.0006739144325256347, 'time_algorithm_update': 0.0058958854675292965, 'loss': 0.6703236441612244, 'td_loss': 0.011746019903104752, 'conservative_loss': 0.6585776240825653, 'time_step': 0.006646929264068603, 'environment': 490.5} step=3000
# 2025-11-20 08:16.21 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_3000.d3
# Epoch 4/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:16.29 [info     ] DiscreteCQL_20251120081553: epoch=4 step=4000 epoch=4 metrics={'time_sample_batch': 0.0005435202121734619, 'time_algorithm_update': 0.004959725856781006, 'loss': 0.6689184150099754, 'td_loss': 0.012678220701869577, 'conservative_loss': 0.6562401951551438, 'time_step': 0.005570543050765991, 'environment': 500.0} step=4000
# 2025-11-20 08:16.29 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_4000.d3
# Epoch 5/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:16.37 [info     ] DiscreteCQL_20251120081553: epoch=5 step=5000 epoch=5 metrics={'time_sample_batch': 0.0005497019290924073, 'time_algorithm_update': 0.004953849315643311, 'loss': 0.6683576420545578, 'td_loss': 0.012532557765953243, 'conservative_loss': 0.6558250844478607, 'time_step': 0.00557426381111145, 'environment': 498.0} step=5000
# 2025-11-20 08:16.37 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_5000.d3
# Epoch 6/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# Moviepy - Building video /content/video/rl-video-episode-64.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-64.mp4
# 2025-11-20 08:16.49 [info     ] DiscreteCQL_20251120081553: epoch=6 step=6000 epoch=6 metrics={'time_sample_batch': 0.0006512250900268555, 'time_algorithm_update': 0.005418478965759277, 'loss': 0.6676212360262871, 'td_loss': 0.013670859806705266, 'conservative_loss': 0.6539503766298294, 'time_step': 0.006152498960494995, 'environment': 500.0} step=6000
# 2025-11-20 08:16.49 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_6000.d3
# Epoch 7/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:16.57 [info     ] DiscreteCQL_20251120081553: epoch=7 step=7000 epoch=7 metrics={'time_sample_batch': 0.0006371803283691406, 'time_algorithm_update': 0.005431913614273072, 'loss': 0.6663102839589119, 'td_loss': 0.013928875437937678, 'conservative_loss': 0.6523814071416855, 'time_step': 0.006151085615158081, 'environment': 500.0} step=7000
# 2025-11-20 08:16.57 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_7000.d3
# Epoch 8/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:17.05 [info     ] DiscreteCQL_20251120081553: epoch=8 step=8000 epoch=8 metrics={'time_sample_batch': 0.0005474681854248047, 'time_algorithm_update': 0.004975006818771362, 'loss': 0.6665084421038627, 'td_loss': 0.014044353659264742, 'conservative_loss': 0.6524640889763832, 'time_step': 0.0055891587734222415, 'environment': 500.0} step=8000
# 2025-11-20 08:17.05 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_8000.d3
# Epoch 9/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:17.13 [info     ] DiscreteCQL_20251120081553: epoch=9 step=9000 epoch=9 metrics={'time_sample_batch': 0.0005490920543670655, 'time_algorithm_update': 0.00504992413520813, 'loss': 0.6888107459545135, 'td_loss': 0.037593278085347265, 'conservative_loss': 0.6512174686789513, 'time_step': 0.005676428079605103, 'environment': 500.0} step=9000
# 2025-11-20 08:17.13 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_9000.d3
# Epoch 10/10:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2025-11-20 08:17.22 [info     ] DiscreteCQL_20251120081553: epoch=10 step=10000 epoch=10 metrics={'time_sample_batch': 0.000663233995437622, 'time_algorithm_update': 0.005516156196594239, 'loss': 0.6795896816253663, 'td_loss': 0.030474356425227597, 'conservative_loss': 0.6491153244972229, 'time_step': 0.006268153905868531, 'environment': 500.0} step=10000
# 2025-11-20 08:17.22 [info     ] Model parameters are saved to d3rlpy_logs/DiscreteCQL_20251120081553/model_10000.d3
# [(1,
#   {'time_sample_batch': 0.0005290753841400147,
#    'time_algorithm_update': 0.0048704886436462405,
#    'loss': 0.705537933588028,
#    'td_loss': 0.035360016939695926,
#    'conservative_loss': 0.6701779159903526,
#    'time_step': 0.005472167491912842,
#    'environment': 500.0}),
#  (2,
#   {'time_sample_batch': 0.000662245512008667,
#    'time_algorithm_update': 0.005823456525802613,
#    'loss': 0.6730708175897598,
#    'td_loss': 0.010519563182722777,
#    'conservative_loss': 0.662551253914833,
#    'time_step': 0.006566694021224975,
#    'environment': 500.0}),
#  (3,
#   {'time_sample_batch': 0.0006739144325256347,
#    'time_algorithm_update': 0.0058958854675292965,
#    'loss': 0.6703236441612244,
#    'td_loss': 0.011746019903104752,
#    'conservative_loss': 0.6585776240825653,
#    'time_step': 0.006646929264068603,
#    'environment': 490.5}),
#  (4,
#   {'time_sample_batch': 0.0005435202121734619,
#    'time_algorithm_update': 0.004959725856781006,
#    'loss': 0.6689184150099754,
#    'td_loss': 0.012678220701869577,
#    'conservative_loss': 0.6562401951551438,
#    'time_step': 0.005570543050765991,
#    'environment': 500.0}),
#  (5,
#   {'time_sample_batch': 0.0005497019290924073,
#    'time_algorithm_update': 0.004953849315643311,
#    'loss': 0.6683576420545578,
#    'td_loss': 0.012532557765953243,
#    'conservative_loss': 0.6558250844478607,
#    'time_step': 0.00557426381111145,
#    'environment': 498.0}),
#  (6,
#   {'time_sample_batch': 0.0006512250900268555,
#    'time_algorithm_update': 0.005418478965759277,
#    'loss': 0.6676212360262871,
#    'td_loss': 0.013670859806705266,
#    'conservative_loss': 0.6539503766298294,
#    'time_step': 0.006152498960494995,
#    'environment': 500.0}),
#  (7,
#   {'time_sample_batch': 0.0006371803283691406,
#    'time_algorithm_update': 0.005431913614273072,
#    'loss': 0.6663102839589119,
#    'td_loss': 0.013928875437937678,
#    'conservative_loss': 0.6523814071416855,
#    'time_step': 0.006151085615158081,
#    'environment': 500.0}),
#  (8,
#   {'time_sample_batch': 0.0005474681854248047,
#    'time_algorithm_update': 0.004975006818771362,
#    'loss': 0.6665084421038627,
#    'td_loss': 0.014044353659264742,
#    'conservative_loss': 0.6524640889763832,
#    'time_step': 0.0055891587734222415,
#    'environment': 500.0}),
#  (9,
#   {'time_sample_batch': 0.0005490920543670655,
#    'time_algorithm_update': 0.00504992413520813,
#    'loss': 0.6888107459545135,
#    'td_loss': 0.037593278085347265,
#    'conservative_loss': 0.6512174686789513,
#    'time_step': 0.005676428079605103,
#    'environment': 500.0}),
#  (10,
#   {'time_sample_batch': 0.000663233995437622,
#    'time_algorithm_update': 0.005516156196594239,
#    'loss': 0.6795896816253663,
#    'td_loss': 0.030474356425227597,
#    'conservative_loss': 0.6491153244972229,
#    'time_step': 0.006268153905868531,
#    'environment': 500.0})]

# %% [markdown]
# Record video!

# %%
import gym
from gym.wrappers import RecordVideo

# start virtual display
d3rlpy.notebook_utils.start_virtual_display()

# wrap RecordVideo wrapper
env = RecordVideo(gym.make("CartPole-v1", render_mode="rgb_array"), './video')

# evaluate
d3rlpy.metrics.evaluate_qlearning_with_environment(cql, env)
# Out:
# /usr/local/lib/python3.12/dist-packages/gym/wrappers/record_video.py:75: UserWarning: WARN: Overwriting existing videos at /content/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# Moviepy - Building video /content/video/rl-video-episode-1.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-1.mp4
# Moviepy - Building video /content/video/rl-video-episode-8.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-8.mp4
# 500.0

# %% [markdown]
# Let's see how it works!

# %%
d3rlpy.notebook_utils.render_video("video/rl-video-episode-1.mp4")
# Out:
#                 <video alt="test" autoplay loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
